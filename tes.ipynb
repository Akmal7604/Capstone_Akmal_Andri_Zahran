# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\UB\\Dicoding\\Datasets\\archive (2)\\recipes.csv')

# %%
df.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# 2  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 3  c("https://img.sndimg.com/food/image/upload/w_...  ...                 3.8
# 4  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 28 columns]

# %%
df.dropna(subset=["RecipeId", "Name", "AuthorId", "AuthorName", "CookTime", "PrepTime", "TotalTime",
    "DatePublished", "Description", "Images", "RecipeCategory", "Keywords",
    "RecipeIngredientQuantities", "RecipeIngredientParts", "AggregatedRating", "ReviewCount",
    "Calories", "FatContent", "SaturatedFatContent", "CholesterolContent", "SodiumContent",
    "CarbohydrateContent", "FiberContent", "SugarContent", "ProteinContent", "RecipeServings", "RecipeInstructions"
], inplace=True)

# %%
df.drop(columns=['RecipeYield'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141788 entries, 0 to 522039
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RecipeId                    141788 non-null  int64
#  1   Name                        141788 non-null  object
#  2   AuthorId                    141788 non-null  int64
#  3   AuthorName                  141788 non-null  object
#  4   CookTime                    141788 non-null  object
#  5   PrepTime                    141788 non-null  object
#  6   TotalTime                   141788 non-null  object
#  7   DatePublished               141788 non-null  object
#  8   Description                 141788 non-null  object
#  9   Images                      141788 non-null  object
#  10  RecipeCategory              141788 non-null  object
#  11  Keywords                    141788 non-null  object
#  12  RecipeIngredientQuantities  141788 non-null  object
#  13  RecipeIngredientParts       141788 non-null  object
#  14  AggregatedRating            141788 non-null  float64
#  15  ReviewCount                 141788 non-null  float64
#  16  Calories                    141788 non-null  float64
#  17  FatContent                  141788 non-null  float64
#  18  SaturatedFatContent         141788 non-null  float64
#  19  CholesterolContent          141788 non-null  float64
#  20  SodiumContent               141788 non-null  float64
#  21  CarbohydrateContent         141788 non-null  float64
#  22  FiberContent                141788 non-null  float64
#  23  SugarContent                141788 non-null  float64
#  24  ProteinContent              141788 non-null  float64
#  25  RecipeServings              141788 non-null  float64
#  26  RecipeInstructions          141788 non-null  object
# dtypes: float64(12), int64(2), object(13)
# memory usage: 30.3+ MB

# %%
df.to_csv('D:\\UB\\Dicoding\\Datasets\\archive (2)\\recipes_clean.csv', index=False)

# %%
unique_categories = df['RecipeCategory'].unique()

print(unique_categories)
# Out:
# ['Frozen Desserts' 'Chicken Breast' 'Beverages' 'Soy/Tofu' 'Vegetable'
#  'Pie' 'Chicken' 'Dessert' 'Southwestern U.S.' 'Stew' 'Black Beans'
#  'Whole Chicken' 'Sauces' 'Brazilian' 'Breakfast' 'Bar Cookie'
#  'Brown Rice' 'Cheese' 'Lamb/Sheep' 'Breads' 'Spaghetti' 'Scones'
#  'Drop Cookies' 'Cheesecake' 'Yeast Breads' 'Low Cholesterol' 'Weeknight'
#  'Low Protein' 'Curries' 'Chicken Livers' '< 60 Mins' '< 30 Mins'
#  'Savory Pies' 'Free Of...' 'Coconut' 'Lunch/Snacks' 'Quick Breads'
#  'Steak' 'Lobster' 'Pork' 'Halibut' 'Crab' 'Potato' 'Pears' 'Meat'
#  'Poultry' 'Very Low Carbs' 'Chowders' 'Tex Mex' 'Onions' 'European'
#  'New Zealand' 'Indonesian' 'Greek' 'Corn' 'Lentil' 'Healthy'
#  'High Protein' 'Summer' 'Long Grain Rice' 'Cauliflower' 'Tuna'
#  'Pineapple' 'Asian' 'Mexican' 'Beans' 'German' 'One Dish Meal'
#  'Short Grain Rice' 'Candy' 'Cajun' 'Oven' 'Rice' 'Microwave' '< 15 Mins'
#  'Apple' 'Jellies' 'Fruit' 'Clear Soup' 'Veal' 'Spanish' 'Shakes'
#  'Orange Roughy' 'Beef Organ Meats' 'Punch Beverage' 'Melons' 'Mussels'
#  'Chicken Thigh & Leg' 'Roast' 'Colombian' 'Manicotti' 'Roast Beef'
#  'Gumbo' 'Turkish' 'White Rice' 'Christmas' 'Spreads' 'Meatloaf' 'Winter'
#  'Trout' 'Smoothies' 'Gelatin' 'Yam/Sweet Potato' 'Oranges' 'Caribbean'
#  'Scandinavian' 'Greens' 'Sourdough Breads' 'High In...' 'Ham' 'Chinese'
#  'Savory' 'Broil/Grill' 'Crawfish' 'Vietnamese' 'Stir Fry'
#  'For Large Groups' 'Raspberries' 'Deer' 'Japanese' 'Hungarian' 'Canadian'
#  'Salad Dressings' 'Thai' 'Spring' 'Vegan' 'Grains' 'Collard Greens'
#  'Tilapia' 'Refrigerator' 'Potluck' 'Spicy' 'Moroccan' 'Catfish'
#  'Chutneys' 'Penne' 'Whole Turkey' 'Pasta Shells' 'Kid Friendly'
#  'Lebanese' 'Spinach' 'Peppers' 'Thanksgiving' 'Whole Duck'
#  'Native American' 'Citrus' 'African' 'Bass' 'Kosher' 'Ethiopian'
#  'Wild Game' 'Rabbit' 'Creole' 'Swedish' 'Goose' 'Squid' 'Swiss'
#  'Lactose Free' 'Perch' 'Elk' 'Duck Breasts' 'Australian'
#  'Medium Grain Rice' 'Berries' 'Tempeh' 'Korean' 'Stocks' 'Cuban'
#  'Strawberry' 'Polish' 'Peanut Butter' 'Southwest Asia (middle East)'
#  'Hawaiian' 'Mahi Mahi' 'Szechuan' 'Portuguese' 'Summer Dip' 'Costa Rican'
#  'Papaya' 'Cantonese' 'Dutch' 'Quail' 'Nuts' 'Filipino' 'Welsh' 'Camping'
#  'Homeopathy/Remedies' 'Turkey Breasts' 'Russian' 'Pheasant' 'Pot Pie'
#  'Bath/Beauty' 'Scottish' 'Polynesian' 'Egyptian' 'Tarts' 'Cherries'
#  'Lime' 'Lemon' 'Duck' 'No Shell Fish' 'Whitefish' 'Brunch'
#  'Tropical Fruits' 'Plums' 'Mango' 'Octopus' 'Household Cleaner' 'Mixer'
#  'Venezuelan' 'Moose' "St. Patrick's Day" '< 4 Hours' 'Toddler Friendly'
#  'Chard' 'Stove Top' 'Malaysian' 'Meatballs' 'Bear' 'Steam' 'Nepalese'
#  'Beginner Cook' 'Palestinian' 'Egg Free' 'Small Appliance' 'No Cook'
#  'Nigerian' 'Icelandic' 'Danish' 'Hunan' 'Halloween' 'High Fiber' 'Iraqi'
#  'Norwegian' 'Pakistani' 'South African' 'Chocolate Chip Cookies'
#  'Kiwifruit' 'Pennsylvania Dutch' 'Czech' 'Finnish' 'Belgian'
#  'Pressure Cooker' 'Easy' 'Puerto Rican' 'South American' 'Sweet'
#  'Ecuadorean' 'Chilean' 'Bread Machine' 'Canning' 'Ham And Bean Soup'
#  'Bread Pudding' 'Austrian' 'Breakfast Eggs' 'Peruvian' 'Bean Soup'
#  'Black Bean Soup' 'Cambodian' 'Oatmeal' 'Artichoke' 'Mushroom Soup'
#  'Avocado' 'Macaroni And Cheese' 'Mashed Potatoes' 'Desserts Fruit'
#  'Pumpkin' 'Ice Cream' 'Memorial Day' 'Indian' 'Sudanese' 'Birthday']

# %%
keyword = df['Keywords'].unique()
print(keyword)
# Out:
# ['c("Dessert", "Low Protein", "Low Cholesterol", "Healthy", "Free Of...", "Summer", "Weeknight", "Freezer", "Easy")'
#  'c("Chicken Thigh & Leg", "Chicken", "Poultry", "Meat", "Asian", "Indian", "Weeknight", "Stove Top")'
#  'c("Low Protein", "Low Cholesterol", "Healthy", "Summer", "< 60 Mins")'
#  ...
#  'c("Greens", "Vegetable", "Pressure Cooker", "< 60 Mins", "Stove Top", "Easy")'
#  'c("Meat", "< 30 Mins", "Easy", "From Scratch")'
#  'c("Breakfast", "Brunch", "< 30 Mins", "Easy", "From Scratch")']
